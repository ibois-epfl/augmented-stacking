# %%
from plot_tri import plot_triangle_cgal

# %%
trace = plot_triangle_cgal('../temp/simlpe_tri/placeTriangulation')
trace.show()

# %%
trace = plot_triangle_cgal('../temp/placeTriangulation')
trace.show()
